# %% [markdown]
# # NFL Defensive Formation Preprocessing
#
# Data preprocessing pipeline for NFL tracking data.
#
# ## Objectives
# 1. Load NFL Big Data Bowl 2021 tracking data
# 2. Standardize coordinate systems
# 3. Extract ball release frames
# 4. Create defensive formation point clouds
# 5. Validate preprocessing with visualizations

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from preprocessing import NFLDataPreprocessor, save_point_clouds, load_point_clouds
from visualization import NFLFieldVisualizer, validate_preprocessing

# %matplotlib inline
plt.style.use('default')

# %% [markdown]
# ## Initialize Preprocessor

# %%
# Initialize preprocessor with path to raw data
preprocessor = NFLDataPreprocessor("../data/raw")

# %% [markdown]
# ## Run Preprocessing Pipeline
#
# This will:
# - Load all data files
# - Merge tracking data with metadata
# - Standardize coordinates (flip plays so offense always goes left-to-right)
# - Extract ball release frames
# - Filter to defensive players only
# - Create point cloud representations

# %%
# Run full pipeline (this may take a few minutes)
defensive_df, point_clouds = preprocessor.preprocess_pipeline(filter_pass_plays=True)
# Out:
# Loading NFL Big Data Bowl 2021 dataset...
# Loaded 253 games
# Loaded 19239 plays
# Loaded 1303 players
# Loading 17 tracking data files...
# Loading weeks: 100%|██████████| 17/17 [01:13<00:00,  4.32s/it]
# Loaded 18309388 tracking records
# Merging tracking data with metadata...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Run full pipeline (this may take a few minutes)
# ----> 2 defensive_df, point_clouds = preprocessor.preprocess_pipeline(filter_pass_plays=True)
#
# File c:\Users\Arjun\OneDrive\Duke\2025-2026\Fall 2025\MATH 412\Final Project\nfl-tda\notebooks\../src\preprocessing.py:299, in NFLDataPreprocessor.preprocess_pipeline(self, filter_pass_plays)
#     296 self.load_data()
#     298 # Merge datasets
# --> 299 merged = self.merge_data()
#     301 # Filter to pass plays if requested
#     302 if filter_pass_plays and 'passResult' in merged.columns:
#
# File c:\Users\Arjun\OneDrive\Duke\2025-2026\Fall 2025\MATH 412\Final Project\nfl-tda\notebooks\../src\preprocessing.py:90, in NFLDataPreprocessor.merge_data(self)
#      88 # Merge with plays data
#      89 if self.plays_data is not None:
# ---> 90     merged = merged.merge(
#      91         self.plays_data,
#      92         on=['gameId', 'playId'],
#      93         how='left'
#      94     )
#      96 # Merge with games data
#      97 if self.games_data is not None:
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\frame.py:10490, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10471 @Substitution("")
#   10472 @Appender(_merge_doc, indents=2)
#   10473 def merge(
#    (...)
#   10486     validate: MergeValidate | None = None,
#   10487 ) -> DataFrame:
#   10488     from pandas.core.reshape.merge import merge
# > 10490     return merge(
#   10491         self,
#   10492         right,
#   10493         how=how,
#   10494         on=on,
#   10495         left_on=left_on,
#   10496         right_on=right_on,
#   10497         left_index=left_index,
#   10498         right_index=right_index,
#   10499         sort=sort,
#   10500         suffixes=suffixes,
#   10501         copy=copy,
#   10502         indicator=indicator,
#   10503         validate=validate,
#   10504     )
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\reshape\merge.py:885, in _MergeOperation.get_result(self, copy)
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     883 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 885 result = self._reindex_and_concat(
#     886     join_index, left_indexer, right_indexer, copy=copy
#     887 )
#     888 result = result.__finalize__(self, method=self._merge_type)
#     890 if self.indicator:
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\reshape\merge.py:876, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     874 left.columns = llabels
#     875 right.columns = rlabels
# --> 876 result = concat([left, right], axis=1, copy=copy)
#     877 return result
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)
#     227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\internals\managers.py:576, in BaseBlockManager.copy(self, deep)
#     573     else:
#     574         new_axes = list(self.axes)
# --> 576 res = self.apply("copy", deep=deep)
#     577 res.axes = new_axes
#     579 if self.ndim > 1:
#     580     # Avoid needing to re-compute these
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Arjun\miniconda3\lib\site-packages\pandas\core\internals\blocks.py:645, in Block.copy(self, deep)
#     643 refs: BlockValuesRefs | None
#     644 if deep:
# --> 645     values = values.copy()
#     646     refs = None
#     647 else:
#
# MemoryError: Unable to allocate 1.23 GiB for an array with shape (9, 18309388) and data type float64

# %% [markdown]
# ## Inspect Results

# %%
# Check dataframe
print(f"Defensive DataFrame shape: {defensive_df.shape}")
print(f"\nColumns: {list(defensive_df.columns)}")
print(f"\nFirst few rows:")
defensive_df.head()

# %%
# Check point clouds
print(f"Number of plays: {len(point_clouds)}")
print(f"\nSample point cloud shape: {list(point_clouds.values())[0].shape}")
print(f"\nAverage defenders per play: {np.mean([pc.shape[0] for pc in point_clouds.values()]):.1f}")

# %% [markdown]
# ## Visualize Sample Formations

# %%
# Create visualizer
visualizer = NFLFieldVisualizer()

# Plot sample formations
fig = visualizer.plot_multiple_formations(point_clouds, n_samples=6)
plt.show()

# %% [markdown]
# ## Check Formation Statistics

# %%
# Plot statistical distributions
fig = visualizer.plot_formation_statistics(point_clouds)
plt.show()

# %% [markdown]
# ## Detailed Look at Individual Formations

# %%
# Pick a random play to examine
sample_play_id = list(point_clouds.keys())[42]
sample_formation = point_clouds[sample_play_id]

print(f"Play: Game {sample_play_id[0]}, Play {sample_play_id[1]}")
print(f"Number of defenders: {sample_formation.shape[0]}")
print(f"\nDefender positions (x, y):")
print(sample_formation)

# %%
# Visualize this formation in detail
fig, ax = plt.subplots(figsize=(14, 7))
visualizer.plot_formation(
    sample_formation,
    ax=ax,
    title=f"Defensive Formation - Game {sample_play_id[0]}, Play {sample_play_id[1]}",
    annotate_players=True,
    player_size=300
)
plt.show()

# %% [markdown]
# ## Save Processed Data
#
# Save the processed data for use in subsequent analysis (TDA computation).

# %%
# Save defensive formations dataframe
defensive_df.to_csv("../data/processed/defensive_formations.csv", index=False)
print("Saved defensive formations CSV")

# Save point clouds
save_point_clouds(point_clouds, "../data/processed/point_clouds.npy")
print("Saved point clouds")

# %% [markdown]
# ## Run Complete Validation
#
# Generate all validation plots and save to results folder.

# %%
# Run validation and save plots
validate_preprocessing(
    defensive_df,
    point_clouds,
    output_dir="../results/figures/preprocessing"
)
